# %%
import pandas as pd

df = pd.read_csv('/content/mushroom_cleaned.csv')
df.head()
# Out:
#    cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 0          1372          2                2          10     3.807467
# 1          1461          2                2          10     3.807467
# 2          1371          2                2          10     3.612496
# 3          1261          6                2          10     3.787572
# 4          1305          6                2          10     3.711971
#
#    stem-width  stem-color    season  class
# 0        1545          11  1.804273    1.0
# 1        1557          11  1.804273    1.0
# 2        1566          11  1.804273    1.0
# 3        1566          11  1.804273    1.0
# 4        1464          11  0.943195    1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17863 entries, 0 to 17862
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cap-diameter     17863 non-null  int64
#  1   cap-shape        17863 non-null  int64
#  2   gill-attachment  17863 non-null  int64
#  3   gill-color       17863 non-null  int64
#  4   stem-height      17863 non-null  float64
#  5   stem-width       17863 non-null  int64
#  6   stem-color       17863 non-null  int64
#  7   season           17862 non-null  float64
#  8   class            17862 non-null  float64
# dtypes: float64(3), int64(6)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#        cap-diameter     cap-shape  gill-attachment    gill-color  \
# count  17863.000000  17863.000000     17863.000000  17863.000000
# mean     519.719532      3.796395         2.239433      8.566758
# std      354.812248      2.239702         2.345708      2.628365
# min        0.000000      0.000000         0.000000      0.000000
# 25%      242.000000      2.000000         0.000000      7.000000
# 50%      495.000000      5.000000         1.000000     10.000000
# 75%      733.000000      6.000000         5.000000     10.000000
# max     1866.000000      6.000000         6.000000     11.000000
#
#         stem-height    stem-width    stem-color        season         class
# count  17863.000000  17863.000000  17863.000000  17862.000000  17862.000000
# mean       0.804681    892.289425      8.390360      0.985202      0.451853
# std        0.705671    711.697333      3.186677      0.310950      0.497690
# min        0.000426      1.000000      0.000000      0.027372      0.000000
# 25%        0.274976    281.000000      6.000000      0.888450      0.000000
# 50%        0.593295    755.000000     10.000000      0.943195      0.000000
# 75%        1.126480   1332.000000     11.000000      0.943195      1.000000
# max        3.835320   3564.000000     12.000000      1.804273      1.000000

# %%
df = df.dropna()

# %%
df['class'] = df['class'].astype(int)

# %%
df.head(3)
# Out:
#    cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 0          1372          2                2          10     3.807467
# 1          1461          2                2          10     3.807467
# 2          1371          2                2          10     3.612496
#
#    stem-width  stem-color    season  class
# 0        1545          11  1.804273      1
# 1        1557          11  1.804273      1
# 2        1566          11  1.804273      1

# %%
from sklearn import set_config
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

set_config(transform_output='pandas')

# %%
columns = df.columns.tolist()
columns.remove('class')

# %%
columns
# Out:
# ['cap-diameter',
#  'cap-shape',
#  'gill-attachment',
#  'gill-color',
#  'stem-height',
#  'stem-width',
#  'stem-color',
#  'season']

# %%
x = df[columns]
y = df['class']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.head()
# Out:
#        cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 4279            803          6                5           3     0.481032
# 764             657          6                0          10     0.863015
# 13555           486          2                0          11     0.091091
# 16041           428          2                5          11     0.322724
# 17553           786          2                5          11     0.676002
#
#        stem-width  stem-color    season
# 4279         1997          10  0.943195
# 764          1140          11  0.888450
# 13555         586           6  0.943195
# 16041        1050          12  0.943195
# 17553        1850          12  0.943195

# %%
trf = ColumnTransformer([('scaler', StandardScaler(), columns)], remainder='passthrough' )

# %%
x_train_trf = trf.fit_transform(x_train)
x_test_trf = trf.transform(x_test)

# %%
x_train_trf
# Out:
#        scaler__cap-diameter  scaler__cap-shape  scaler__gill-attachment  \
# 4279               0.805873           0.980725                 1.173858
# 764                0.392553           0.980725                -0.957541
# 13555             -0.091542          -0.805070                -0.957541
# 16041             -0.255738          -0.805070                 1.173858
# 17553              0.757747          -0.805070                 1.173858
# ...                     ...                ...                      ...
# 11284             -0.663396          -1.697967                -0.957541
# 11964             -1.382460           0.980725                -0.957541
# 5390               0.171738           0.534276                -0.531261
# 860                2.144918          -0.805070                -0.957541
# 15795              0.698297          -0.805070                 1.173858
#
#        scaler__gill-color  scaler__stem-height  scaler__stem-width  \
# 4279            -2.140815            -0.461196            1.563601
# 764              0.542662             0.078847            0.352977
# 13555            0.926016            -1.012490           -0.429620
# 16041            0.926016            -0.685010            0.225840
# 17553            0.926016            -0.185549            1.355944
# ...                   ...                  ...                 ...
# 11284           -2.140815            -0.808770           -0.542630
# 11964            0.926016             0.524461           -1.240470
# 5390             0.542662             0.181309           -0.161220
# 860              0.542662             2.171514            1.193492
# 15795            0.926016             0.343243            0.468813
#
#        scaler__stem-color  scaler__season
# 4279             0.505156       -0.126437
# 764              0.818730       -0.303977
# 13555           -0.749142       -0.126437
# 16041            1.132305       -0.126437
# 17553            1.132305       -0.126437
# ...                   ...             ...
# 11284            0.505156       -0.303977
# 11964            1.132305       -0.303977
# 5390             0.818730       -0.126437
# 860              0.818730       -0.126437
# 15795           -0.435568       -0.126437
#
# [14289 rows x 8 columns]

# %%
lr = LogisticRegression()
lr.fit(x_train_trf, y_train)
# Out:
# LogisticRegression()

# %%
pred = lr.predict(x_test_trf)

# %%
score = accuracy_score(y_test, pred)*100
score
# Out:
# 71.11670864819479

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(x_train_trf, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_new = dtc.predict(x_test_trf)

# %%
new_score = accuracy_score(y_test, pred_new)*100
new_score
# Out:
# 98.2367758186398
